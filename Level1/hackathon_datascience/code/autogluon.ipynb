# %%
# !pip uninstall -y scikit-learn imbalanced-learn autogluon autogluon.core autogluon.tabular
# Out:
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Successfully uninstalled scikit-learn-1.5.2
# WARNING: Skipping imbalanced-learn as it is not installed.
# Found existing installation: autogluon 1.2
# Uninstalling autogluon-1.2:
#   Successfully uninstalled autogluon-1.2
# Found existing installation: autogluon.core 1.2
# Uninstalling autogluon.core-1.2:
#   Successfully uninstalled autogluon.core-1.2
# Found existing installation: autogluon.tabular 1.2
# Uninstalling autogluon.tabular-1.2:
#   Successfully uninstalled autogluon.tabular-1.2

# %%
# !pip install -U "scikit-learn==1.3.0"
# !pip install -U autogluon
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 94.2 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-timeseries 1.2 requires autogluon.core[raytune]==1.2, which is not installed.
# autogluon-timeseries 1.2 requires autogluon.tabular[catboost,lightgbm,xgboost]==1.2, which is not installed.
# autogluon-multimodal 1.2 requires autogluon.core[raytune]==1.2, which is not installed.
# autogluon-features 1.2 requires scikit-learn<1.5.3,>=1.4.0, but you have scikit-learn 1.3.0 which is incompatible.
# autogluon-multimodal 1.2 requires scikit-learn<1.5.3,>=1.4.0, but you have scikit-learn 1.3.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.3.0 which is incompatible.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.2/266.2 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -U "scikit-learn==1.3.0"
# Out:
# ...
#   Using cached scikit_learn-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
# Using cached scikit_learn-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-tabular 1.2 requires scikit-learn<1.5.3,>=1.4.0, but you have scikit-learn 1.3.0 which is incompatible.
# autogluon-core 1.2 requires scikit-learn<1.5.3,>=1.4.0, but you have scikit-learn 1.3.0 which is incompatible.
# autogluon-features 1.2 requires scikit-learn<1.5.3,>=1.4.0, but you have scikit-learn 1.3.0 which is incompatible.
# ...

# %%
import sklearn
import autogluon.core

print("Scikit-learn version:", sklearn.__version__)
print("AutoGluon version:", autogluon.core.__version__)
# Out:
# Scikit-learn version: 1.3.0
# AutoGluon version: 1.2

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/cleaned_data.csv')
df
# Out:
#         High_Blood_Pressure  Told_High_Cholesterol  Cholesterol_Checked  \
# 0                         0                      0                    1
# 1                         0                      0                    0
# 2                         0                      0                    0
# 3                         0                      0                    1
# 4                         0                      0                    1
# ...                     ...                    ...                  ...
# 325299                    1                      0                    1
# 325300                    1                      1                    1
# 325301                    1                      1                    1
# 325302                    1                      0                    1
# 325303                    0                      0                    1
#
#         Body_Mass_Index  Smoked_100_Cigarettes  Diagnosed_Stroke  \
# ...

# %%
from autogluon.tabular import TabularPredictor

predictor = TabularPredictor(label="History_of_HeartDisease_or_Attack").fit(df)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20250214_175110"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Memory Avail:       11.00 GB / 12.67 GB (86.8%)
# Disk Space Avail:   75.33 GB / 107.72 GB (69.9%)
# ...
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# ...

# %%
predictor.save("autogluon_best_model")

# %%
best_model = predictor.model_best
print("Best model:", best_model)
# Out:
# Best model: WeightedEnsemble_L2

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
X_val = pd.read_csv('/content/X_eval.csv')
y_val = pd.read_csv('/content/y_eval.csv')

# %%
X_val
# Out:
#        High_Blood_Pressure  Told_High_Cholesterol  Cholesterol_Checked  \
# 0                        1                      1                    1
# 1                        1                      1                    1
# 2                        1                      1                    1
# 3                        0                      0                    1
# 4                        0                      1                    1
# ...                    ...                    ...                  ...
# 44272                    0                      0                    1
# 44273                    0                      0                    1
# 44274                    0                      1                    1
# 44275                    0                      0                    1
# 44276                    1                      1                    1
#
#        Body_Mass_Index  Smoked_100_Cigarettes  Diagnosed_Stroke  \
# ...

# %%
X_val.drop(columns=['Unnamed_0'] ,inplace=True)

# %%
X_val.columns = X_val.columns.str.strip().str.replace(" ", "_").str.replace("[^a-zA-Z0-9_]", "", regex=True)

# %%
X_test = pd.read_csv('/content/test_imputed.csv')

# %%
y_pred = predictor.predict(X_test)

# %%
y_pred
# Out:
# Empty DataFrame
# Columns: [y_pred]
# Index: []

# %%
sample_sub = pd.read_csv('/content/sample_submission.csv')
sample_sub
# Out:
#                 ID History of HeartDisease or Attack
# 0      test_000001                                No
# 1      test_000002                                No
# 2      test_000003                                No
# 3      test_000004                               NaN
# 4      test_000005                               NaN
# ...            ...                               ...
# 74356  test_074357                               NaN
# 74357  test_074358                               NaN
# 74358  test_074359                               NaN
# 74359  test_074360                               NaN
# 74360  test_074361                               NaN
#
# [74361 rows x 2 columns]

# %%
sample_sub
# Out:
#                 ID
# 0      test_000001
# 1      test_000002
# 2      test_000003
# 3      test_000004
# 4      test_000005
# ...            ...
# 74356  test_074357
# 74357  test_074358
# 74358  test_074359
# 74359  test_074360
# 74360  test_074361
#
# [74361 rows x 1 columns]

# %%
import pandas as pd

# Ensure y_pred is a DataFrame
y_pred = pd.read_csv('/content/submit.csv')

# Concatenate along columns
submission = pd.concat([sample_sub, y_pred], axis=1)
submission.rename(columns={"History_of_HeartDisease_or_Attack": "History of HeartDisease or Attack"}, inplace=True)

submission["History of HeartDisease or Attack"] = submission["History of HeartDisease or Attack"].map({1: "Yes", 0: "No"})

# Save to CSV
submission.to_csv("submission.csv", index=False)

# Display the first few rows
submission
# Out:
#                 ID History of HeartDisease or Attack
# 0      test_000001                               Yes
# 1      test_000002                               Yes
# 2      test_000003                               Yes
# 3      test_000004                                No
# 4      test_000005                                No
# ...            ...                               ...
# 74356  test_074357                                No
# 74357  test_074358                               Yes
# 74358  test_074359                                No
# 74359  test_074360                               Yes
# 74360  test_074361                                No
#
# [74361 rows x 2 columns]

# %%
sample_sub.drop(columns=['History of HeartDisease or Attack'] ,inplace=True)

# %%
|y_pred.to_csv('/content/submit.csv' ,index=False)

# %%
accuracy = accuracy_score(y_val, y_pred)
report = classification_report(y_val, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.8522
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92     40664
#            1       0.25      0.41      0.31      3613
#
#     accuracy                           0.85     44277
#    macro avg       0.60      0.65      0.61     44277
# weighted avg       0.89      0.85      0.87     44277

# %%
y_pred
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 44272    0
# 44273    0
# 44274    0
# 44275    0
# 44276    0
# Name: History_of_HeartDisease_or_Attack, Length: 44277, dtype: int64

# %%
y_pred.value_counts()
# Out:
# History_of_HeartDisease_or_Attack
# 0    38391
# 1     5886
# Name: count, dtype: int64

# %%
best_model
# Out:
# 'WeightedEnsemble_L2'

# %%
y_val
# Out:
#        History_of_HeartDisease_or_Attack
# 0                                      1
# 1                                      1
# 2                                      0
# 3                                      0
# 4                                      0
# ...                                  ...
# 44272                                  0
# 44273                                  0
# 44274                                  0
# 44275                                  0
# 44276                                  1
#
# [44277 rows x 1 columns]

# %%
y_val.columns = y_val.columns.str.strip().str.replace(" ", "_").str.replace("[^a-zA-Z0-9_]", "", regex=True)

# %%
y_val.drop(columns=['Unnamed: 0'] ,inplace=True)
